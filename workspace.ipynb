# %%
import pandas as pd
import numpy as np
import sys
import os

print("🌌 SPACE TECH WORKSTATION ONLINE")
print("-" * 35)
print(f"Project Workspace Directory: {os.getcwd()}")
print(f"Python Engine Path: {sys.executable}")
print(f"Libraries Active: Pandas v{pd.__version__} | NumPy v{np.__version__}")
# Out:
# 🌌 SPACE TECH WORKSTATION ONLINE
# -----------------------------------
# Project Workspace Directory: d:\space-ml-journey
# Python Engine Path: d:\conda_envs\ml-env\python.exe
# Libraries Active: Pandas v3.0.3 | NumPy v2.4.6

# %%
import numpy as np
import pandas as pd

# 🌌 Let's auto-generate a mock dataset of 5 tracking satellites
data = {
    "Satellite_ID": [f"SAT-{i}" for i in range(101, 106)],
    "Orbital_Velocity_(km/s)": np.round(np.random.uniform(7.5, 7.9, 5), 2),
    "Signal_Status": ["Active", "Operational", "Degraded", "Active", "Operational"],
}

# Convert our raw dictionary into a beautifully structured Pandas DataFrame table
df = pd.DataFrame(data)

print("✅ Data Pipeline Running Flawlessly on D-Drive!\n")
print(df)
# Out:
# ✅ Data Pipeline Running Flawlessly on D-Drive!
#
#   Satellite_ID  Orbital_Velocity_(km/s) Signal_Status
# 0      SAT-101                     7.56        Active
# 1      SAT-102                     7.60   Operational
# 2      SAT-103                     7.89      Degraded
# 3      SAT-104                     7.55        Active
# 4      SAT-105                     7.85   Operational
